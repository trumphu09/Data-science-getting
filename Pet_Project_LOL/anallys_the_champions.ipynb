# %% [markdown]
# ### All champions in LOL

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cham_lol = pd.read_csv("LoL_champions.csv")
cham_lol.head(6)
# Out:
#       Name               Tags            Role Range type Resourse type  \
# 0   Aatrox            Fighter             Top      Melee    Blood Well
# 1     Ahri      Mage,Assassin          Middle     Ranged          Mana
# 2    Akali           Assassin      Top,Middle      Melee        Energy
# 3   Akshan  Marksman,Assassin          Middle     Ranged          Mana
# 4  Alistar       Tank,Support         Support      Melee          Mana
# 5    Amumu       Tank,Support  Jungle,Support      Melee          Mana
#
#    Base HP  HP per lvl  Base mana  Mana per lvl  Movement speed  ...  \
# 0      650         114          0           0.0             345  ...
# 1      590         104        418          25.0             330  ...
# 2      600         119        200           0.0             345  ...
# 3      630         107        350          40.0             330  ...
# 4      685         120        350          40.0             330  ...
# ...

# %%
cham_lol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Name                       167 non-null    object
#  1   Tags                       167 non-null    object
#  2   Role                       167 non-null    object
#  3   Range type                 167 non-null    object
#  4   Resourse type              160 non-null    object
#  5   Base HP                    167 non-null    int64
#  6   HP per lvl                 167 non-null    int64
#  7   Base mana                  167 non-null    int64
#  8   Mana per lvl               167 non-null    float64
#  9   Movement speed             167 non-null    int64
#  10  Base armor                 167 non-null    int64
#  11  Armor per lvl              167 non-null    float64
#  12  Base magic resistance      167 non-null    int64
# ...

# %%
cham_lol.describe()
# Out:
#           Base HP  HP per lvl   Base mana  Mana per lvl  Movement speed  \
# count  167.000000  167.000000  167.000000    167.000000      167.000000
# mean   617.856287  104.059880  313.586826     36.712575      336.155689
# std     39.468040    8.687133  122.071293     19.780376        7.060817
# min    410.000000   69.000000    0.000000      0.000000      325.000000
# 25%    595.500000   99.000000  280.000000     25.500000      330.000000
# 50%    625.000000  104.000000  330.000000     40.000000      335.000000
# 75%    645.000000  109.000000  392.500000     50.000000      340.000000
# max    696.000000  129.000000  530.000000     87.000000      355.000000
#
#        Base armor  Armor per lvl  Base magic resistance  \
# count  167.000000      167.00000             167.000000
# mean    29.886228        4.64521              30.760479
# std      6.400696        0.51391               1.701203
# min     18.000000        0.00000              22.000000
# ...

# %%
#how many unique champion in LoL 
print(cham_lol.Name.nunique())

cham_lol.Name.unique()
# Out:
# 167
# array(['Aatrox', 'Ahri', 'Akali', 'Akshan', 'Alistar', 'Amumu', 'Anivia',
#        'Annie', 'Aphelios', 'Ashe', 'Aurelion Sol', 'Azir', 'Bard',
#        "Bel'Veth", 'Blitzcrank', 'Brand', 'Braum', 'Briar', 'Caitlyn',
#        'Camille', 'Cassiopeia', "Cho'Gath", 'Corki', 'Darius', 'Diana',
#        'Draven', 'Dr. Mundo', 'Ekko', 'Elise', 'Evelynn', 'Ezreal',
#        'Fiddlesticks', 'Fiora', 'Fizz', 'Galio', 'Gangplank', 'Garen',
#        'Gnar', 'Gragas', 'Graves', 'Gwen', 'Hecarim', 'Heimerdinger',
#        'Hwei', 'Illaoi', 'Irelia', 'Ivern', 'Janna', 'Jarvan IV', 'Jax',
#        'Jayce', 'Jhin', 'Jinx', "Kai'Sa", 'Kalista', 'Karma', 'Karthus',
#        'Kassadin', 'Katarina', 'Kayle', 'Kayn', 'Kennen', "Kha'Zix",
#        'Kindred', 'Kled', "Kog'Maw", "K'Sante", 'LeBlanc', 'Lee Sin',
#        'Leona', 'Lillia', 'Lissandra', 'Lucian', 'Lulu', 'Lux',
#        'Malphite', 'Malzahar', 'Maokai', 'Master Yi', 'Milio',
# ...

# %%
cham_lol.shape
# Out:
# (167, 24)

# %%
# missing values
cham_lol.isnull().sum()
# Out:
# Name                         0
# Tags                         0
# Role                         0
# Range type                   0
# Resourse type                7
# Base HP                      0
# HP per lvl                   0
# Base mana                    0
# Mana per lvl                 0
# Movement speed               0
# Base armor                   0
# Armor per lvl                0
# Base magic resistance        0
# Magic resistance per lvl     0
# Attack range                 0
# HP regeneration              0
# HP regeneration per lvl      0
# Mana regeneration            0
# Mana regeneration per lvl    0
# Attack damage                0
# Attack damage per lvl        0
# Attack speed per lvl         0
# Attack speed                 0
# AS ratio                     0
# dtype: int64

# %%
# missing data in resourse tpye column
print(cham_lol["Resourse type"])
cham_lol = cham_lol.fillna(0)
# Out:
# 0      Blood Well
# 1            Mana
# 2          Energy
# 3            Mana
# 4            Mana
#           ...
# 162          Mana
# 163          Mana
# 164          Mana
# 165          Mana
# 166          Mana
# Name: Resourse type, Length: 167, dtype: object

# %%
# information of yasuo
cham_lol.loc[cham_lol.Name == "Yasuo"]
# Out:
#       Name              Tags               Role Range type Resourse type  \
# 156  Yasuo  Fighter,Assassin  Top,Middle,Bottom      Melee          Flow
#
#      Base HP  HP per lvl  Base mana  Mana per lvl  Movement speed  ...  \
# 156      590         110        100           0.0             345  ...
#
#      Attack range  HP regeneration  HP regeneration per lvl  \
# 156           175              6.5                      0.9
#
#      Mana regeneration  Mana regeneration per lvl  Attack damage  \
# 156                0.0                        0.0             60
#
#      Attack damage per lvl  Attack speed per lvl  Attack speed  AS ratio
# 156                    3.0                   3.5         0.697      0.67
#
# [1 rows x 24 columns]

# %%
# How many champions have more than 600 base_hp ?
cham_lol.loc[cham_lol["Base HP"] > 600].Name.count()
# Out:
# np.int64(112)

# %%
# How many champions in each different lane ?
cham_lol.Role.value_counts()
# Out:
# Role
# Top                          27
# Jungle                       26
# Middle                       22
# Support                      21
# Bottom                       17
# Middle,Support                6
# Top,Middle                    5
# Top,Jungle                    5
# Jungle,Top                    4
# Bottom,Support                4
# Jungle,Middle                 3
# Support,Middle                3
# Top,Support                   3
# Bottom,Middle                 2
# Middle,Jungle                 2
# Jungle,Support                2
# Middle,Top                    2
# Bottom,Top                    1
# Middle,Bottom,Top             1
# Top,Middle,Bottom             1
# Top,Jungle,Support            1
# Middle,Support,Top            1
# Bottom,Top,Middle             1
# Top,Support,Jungle,Middle     1
# Support,Jungle                1
# Top,Middle,Support            1
# Support,Top,Middle            1
# Jungle,Top,Middle             1
# Jungle,Support,Middle         1
# ...

# %%
# different role 
cham_lol.Tags.value_counts()
# Out:
# Tags
# Fighter,Tank         19
# Fighter,Assassin     16
# Mage,Support         15
# Mage                 14
# Support,Mage         12
# Marksman             10
# Marksman,Mage         9
# Tank,Support          9
# Assassin,Mage         7
# Marksman,Assassin     7
# Tank,Fighter          6
# Fighter               6
# Assassin              6
# Tank,Mage             5
# Fighter,Mage          5
# Assassin,Fighter      4
# Tank                  4
# Mage,Marksman         3
# Mage,Assassin         2
# Support,Tank          2
# Marksman,Support      1
# Marksman,Fighter      1
# Support,Assassin      1
# Support               1
# Support,Marksman      1
# Mage,Fighter          1
# Name: count, dtype: int64

# %%
cham_lol.columns = cham_lol.columns.str.replace(' ', '_')

# %%
# Which has a higher average base armor: melee or ranged champions?
cham_lol.groupby("Range_type").Base_armor.mean()
# Out:
# Range_type
# Melee     33.886364
# Ranged    25.430380
# Name: Base_armor, dtype: float64

# %%
#top 5 cham has highest base AD
top5 = cham_lol.sort_values(by = "Attack_damage",ascending = False ).head(5)

'''
By selecting one of the top 5 champions with the highest base attack damage in LoL, 
players can gain a significant early-game advantage and dominate the laning phase.'''
# Out:
# '\nBy selecting one of the top 5 champions with the highest base attack damage in LoL, \nplayers can gain a significant early-game advantage and dominate the laning phase.'

# %%
top5.plot(kind='bar', color='red', title='Top Champions by Damage')
# Out:
# <Axes: title={'center': 'Top Champions by Damage'}>

# %%
# in assassin's world 
As = cham_lol.loc[cham_lol.Tags == "Assassin"]
As
# Out:
#         Name      Tags            Role Range_type Resourse_type  Base_HP  \
# 2      Akali  Assassin      Top,Middle      Melee        Energy      600
# 62   Kha'Zix  Assassin          Jungle      Melee          Mana      643
# 98    Qiyana  Assassin          Middle      Melee          Mana      590
# 115    Shaco  Assassin  Jungle,Support      Melee          Mana      630
# 130    Talon  Assassin   Middle,Jungle      Melee          Mana      658
# 161      Zed  Assassin   Middle,Jungle      Melee        Energy      654
#
#      HP_per_lvl  Base_mana  Mana_per_lvl  Movement_speed  ...  Attack_range  \
# 2           119        200           0.0             345  ...           125
# 62           99        327          40.0             350  ...           125
# 98          124        375          60.0             335  ...           150
# 115          99        297          40.0             345  ...           125
# ...

# %%
As.sort_values(by = "Movement_speed",ascending = False)
# Out:
#         Name      Tags            Role Range_type Resourse_type  Base_HP  \
# 62   Kha'Zix  Assassin          Jungle      Melee          Mana      643
# 2      Akali  Assassin      Top,Middle      Melee        Energy      600
# 115    Shaco  Assassin  Jungle,Support      Melee          Mana      630
# 161      Zed  Assassin   Middle,Jungle      Melee        Energy      654
# 98    Qiyana  Assassin          Middle      Melee          Mana      590
# 130    Talon  Assassin   Middle,Jungle      Melee          Mana      658
#
#      HP_per_lvl  Base_mana  Mana_per_lvl  Movement_speed  ...  Attack_range  \
# 62           99        327          40.0             350  ...           125
# 2           119        200           0.0             345  ...           125
# 115          99        297          40.0             345  ...           125
# 161          99        200           0.0             345  ...           125
# ...

# %%
# highest HP at late 
cham_lol['Hp_level_18'] = cham_lol['Base_HP'] + cham_lol['HP_per_lvl'] * 17
cham_lol.Hp_level_18.sort_values(ascending = False )
cham_lol.sort_values(by = "Hp_level_18", ascending = False)
# Out:
#         Name              Tags            Role Range_type Resourse_type  \
# 34     Galio         Tank,Mage  Middle,Support      Melee          Mana
# 126    Sylas     Mage,Assassin      Middle,Top      Melee          Mana
# 109     Ryze              Mage          Middle     Ranged          Mana
# 4    Alistar      Tank,Support         Support      Melee          Mana
# 98    Qiyana          Assassin          Middle      Melee          Mana
# ..       ...               ...             ...        ...           ...
# 79     Milio      Support,Mage         Support     Ranged          Mana
# 112    Senna  Support,Marksman  Bottom,Support     Ranged          Mana
# 37      Gnar      Fighter,Tank             Top     Ranged          Rage
# 64      Kled           Fighter             Top      Melee       Courage
# 159    Yuumi      Support,Mage         Support     Ranged          Mana
#
#      Base_HP  HP_per_lvl  Base_mana  Mana_per_lvl  Movement_speed  ...  \
# ...

# %%
# ass melee or mage range has higher mov speed
ass_melle = cham_lol.groupby(["Tags", "Range_type"]).Movement_speed.mean().sort_values(ascending = False)
ass_melle
# Out:
# Tags               Range_type
# Fighter            Melee         344.166667
# Assassin,Fighter   Melee         343.750000
# Fighter,Tank       Melee         343.529412
# Assassin           Melee         342.500000
# Fighter,Assassin   Melee         342.500000
# Tank,Mage          Melee         342.000000
# Tank,Fighter       Melee         340.000000
# Mage,Assassin      Melee         340.000000
# Support,Tank       Melee         340.000000
# Fighter,Mage       Melee         338.000000
# Tank               Melee         337.500000
# Assassin,Mage      Melee         336.250000
# Support            Melee         335.000000
# Marksman,Fighter   Melee         335.000000
# Mage,Support       Ranged        335.000000
# Mage,Marksman      Melee         335.000000
# Assassin,Mage      Ranged        335.000000
# Mage               Ranged        333.071429
# Mage,Marksman      Ranged        332.500000
# Fighter,Tank       Ranged        332.500000
# Tank,Support       Melee         331.111111
# ...

# %%
#Advanced screening
cham_lol.loc[ (cham_lol['Tags'].isin(["Fighter"])) & (cham_lol.Range_type == "Melee")  & (cham_lol.Attack_damage > 60) ]
# Out:
#          Name     Tags        Role Range_type Resourse_type  Base_HP  \
# 35  Gangplank  Fighter         Top      Melee          Mana      630
# 40       Gwen  Fighter         Top      Melee          Mana      620
# 49        Jax  Fighter  Top,Jungle      Melee          Mana      665
# 64       Kled  Fighter         Top      Melee       Courage      410
#
#     HP_per_lvl  Base_mana  Mana_per_lvl  Movement_speed  ...  HP_regeneration  \
# 35         114        280          60.0             345  ...              6.0
# 40         115        330          40.0             340  ...              9.0
# 49         100        339          52.0             350  ...              8.5
# 64          84        100           0.0             345  ...              6.0
#
#     HP_regeneration_per_lvl  Mana_regeneration  Mana_regeneration_per_lvl  \
# 35                     0.60                7.5                        0.7
# 40                     0.90                7.5                        0.7
# ...

# %%
cham_lol.head()
# Out:
#       Name               Tags        Role Range_type Resourse_type  Base_HP  \
# 0   Aatrox            Fighter         Top      Melee    Blood Well      650
# 1     Ahri      Mage,Assassin      Middle     Ranged          Mana      590
# 2    Akali           Assassin  Top,Middle      Melee        Energy      600
# 3   Akshan  Marksman,Assassin      Middle     Ranged          Mana      630
# 4  Alistar       Tank,Support     Support      Melee          Mana      685
#
#    HP_per_lvl  Base_mana  Mana_per_lvl  Movement_speed  ...  HP_regeneration  \
# 0         114          0           0.0             345  ...             3.00
# 1         104        418          25.0             330  ...             2.50
# 2         119        200           0.0             345  ...             9.00
# 3         107        350          40.0             330  ...             3.75
# 4         120        350          40.0             330  ...             8.50
#
# ...

# %%
cham_lol.loc[cham_lol.Name == "Aatrox"]
# Out:
#      Name     Tags Role Range_type Resourse_type  Base_HP  HP_per_lvl  \
# 0  Aatrox  Fighter  Top      Melee    Blood Well      650         114
#
#    Base_mana  Mana_per_lvl  Movement_speed  ...  HP_regeneration  \
# 0          0           0.0             345  ...              3.0
#
#    HP_regeneration_per_lvl  Mana_regeneration  Mana_regeneration_per_lvl  \
# 0                      0.5                0.0                        0.0
#
#    Attack_damage  Attack_damage_per_lvl  Attack_speed_per_lvl  Attack_speed  \
# 0             60                    5.0                   2.5         0.651
#
#    AS_ratio  Hp_level_18
# 0     0.651         2588
#
# [1 rows x 25 columns]
